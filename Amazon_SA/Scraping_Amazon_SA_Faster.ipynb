# %% [markdown]
# # At First Scraping The Data

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import random
from concurrent.futures import ThreadPoolExecutor, as_completed
from collections import defaultdict
import pandas as pd

category_name_list = []
all_phones_pages_link_list = []
all_phones_link_list = []
all_headphones_pages_link_list = []
all_headphones_link_list = []
all_covers_pages_link_list = []
all_covers_link_list = []
all_screens_pages_link_list = []
all_screens_link_list = []
all_power_banks_pages_link_list = []
all_power_banks_link_list = []
all_chargers_pages_link_list = []
all_chargers_link_list = []
headers = {
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
"Accept-Encoding": "gzip, deflate",
"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,/;q=0.8",
"DNT": "1",
"Connection": "close",
"Upgrade-Insecure-Requests": "1",
}
def scrape_proxies(url, limit=101):
    try:
        # Fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for bad status codes
        
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all table rows
        rows = soup.find_all('tr')
        
        # Extract IP and Port from each row and format as requested
        proxies = [
            {'http': f"{row.find_all('td')[0].text}:{row.find_all('td')[1].text}"}
            for row in rows[:limit]
            if len(row.find_all('td')) >= 2
        ]
        
        return proxies
    
    except requests.RequestException as e:
        # print(f"An error occurred while fetching the webpage: {e}")
        return []
    except Exception as e:
        # print(f"An unexpected error occurred: {e}")
        return []

mohamed = "https://free-proxy-list.net"  # Replace with the actual mohamed
proxies = scrape_proxies(mohamed)

for i in range(1,34):
    product_link = f'https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page={i}&language=en_AE'
    all_phones_pages_link_list.append(product_link)
proxy_failures = defaultdict(int)
MAX_FAILURES = 101
def get_proxy():
    working_proxies = [p for p, failures in proxy_failures.items() if failures < MAX_FAILURES]
    return random.choice(working_proxies) if working_proxies else None


def get_text_or_none(tag, attribute_name=None):
    if tag:
        if attribute_name:
            return tag.get(attribute_name, None)
        return tag.get_text(strip=True)
    return None
def make_request(url, max_retries=51):        
    for attempt in range(max_retries):
        proxy = get_proxy()
        if not proxy:
            # print("No working proxies available. Trying without proxy.")
            try:
                response = requests.get(url, headers=headers)
                response.raise_for_status()
                return response
            except requests.RequestException as e:
                # print(f"Attempt {attempt + 1} failed without proxy: {e}")
                time.sleep(random.uniform(1, 2))
                continue

        try:
            response = requests.get(url, headers=headers, proxies={'http': proxy})
            response.raise_for_status()
            return response
        except requests.RequestException as e:
            # print(f"Attempt {attempt + 1} failed with proxy {proxy}: {e}")
            proxy_failures[proxy] += 1
            if proxy_failures[proxy] >= MAX_FAILURES:
                # print(f"Proxy {proxy} has failed {MAX_FAILURES} times and will no longer be used.")
                time.sleep(random.uniform(1, 2))
    
    # raise Exception(f"Failed to retrieve {url} after {max_retries} attempts")

def get_all_phones_link(link, max_retries=35):
    retry_count = 0
    
    while retry_count < max_retries:
        try:
            page = make_request(link)
            soup = BeautifulSoup(page.content, "html.parser")
            all_phones = soup.find_all("div", class_="a-section a-spacing-none a-spacing-top-small s-title-instructions-style")
            
            if all_phones:
                for phone in all_phones:
                    phone_link = phone.find_all("a")[0].get("href")
                    phone_link = f"https://www.amazon.sa{phone_link}"
                    all_phones_link_list.append(phone_link)
                
                print(f"Found {len(all_phones)} phones on page {link}")
                return
            
            else:
                retry_count += 1
                # print(f"No phones found on page {link}, retrying... ({retry_count}/{max_retries})")
                time.sleep(random.uniform(1, 2))  # Random delay before retrying

        except Exception as e:
            # print(f"Error getting phone links from {link}: {e}")
            retry_count += 1
            time.sleep(random.uniform(1, 2))  # Random delay before retrying
    
    # print(f"Failed to find phones on {link} after {max_retries} retries")


# Modified scrape_product_data function
def scrape_product_data(link, max_retries=500):
    for attempt in range(max_retries):
        # time.sleep(random.uniform(1, 2))
        try:
            page = make_request(link)
            soup = BeautifulSoup(page.content, "html.parser")

        
            camera_info = None
            for li in soup.find_all('li', class_='a-spacing-mini'):
                if 'MP' in li.text:
                    camera_info = re.search(r'(\d+MP)', li.text)
                    if camera_info:
                        camera_info = camera_info.group(1)
                        break
    
            color_row = soup.find('tr', class_='a-spacing-small po-color')
            color = None  # Initialize color
            if color_row:
                # If the color row exists, find the span inside it and get the text
                color = get_text_or_none(color_row.find('span', class_='a-size-base po-break-word'))
            
            elif soup.find('table', id ='productDetails_techSpec_section_1'):
                color_row2 = soup.find('th', string='Color')
                if color_row2:
                    color = color_row2.find_next('td').get_text(strip=True)
            
            else:
                # Check for color in div with id='variation_color_name'
                outerSelect = soup.find('div', id='variation_color_name')
                if outerSelect:
                    selection_row = outerSelect.find('span', class_='selection')
                    if selection_row:
                        color = get_text_or_none(selection_row)
    
            price = get_text_or_none(soup.find('div', class_='a-section a-spacing-micro').find('span', class_='a-offscreen')
                        if soup.find('div', class_='a-section a-spacing-micro') else None)
            if not price:
                price = get_text_or_none(soup.find('span', class_='a-price-whole'))
    
            Website = 'Amazon SA'
            Currency = 'SAR'
    
            # Extract other product data
            data = {
                # "category": category_name_list[0] if category_name_list else "unknown-category",
                "Title": get_text_or_none(soup.find('span', id='productTitle')),
                "Brand": get_text_or_none(soup.find('tr', class_='a-spacing-small po-brand').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-brand') else None),
                "OS": get_text_or_none(soup.find('tr', class_='a-spacing-small po-operating_system').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-operating_system') else None),
                "RAM": get_text_or_none(soup.find('tr', class_='a-spacing-small po-ram_memory.installed_size').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-ram_memory.installed_size') else None),
                "CPU": get_text_or_none(soup.find('tr', class_='a-spacing-small po-cpu_model.family').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-cpu_model.family') else None),
                "Storage": get_text_or_none(soup.find('tr', class_='a-spacing-small po-memory_storage_capacity').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-memory_storage_capacity') else None),
                "Screen Size": get_text_or_none(soup.find('tr', class_='a-spacing-small po-display.size').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-display.size') else None),
                "Resolution": get_text_or_none(soup.find('tr', class_='a-spacing-small po-resolution').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-resolution') else None),
                "CPU Speed": get_text_or_none(soup.find('tr', class_='a-spacing-small po-cpu_model.speed').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-cpu_model.speed') else None),
                "Model": get_text_or_none(soup.find('tr', class_='a-spacing-small po-model_name').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-model_name') else None),
                "Wireless Provider": get_text_or_none(soup.find('tr', class_='a-spacing-small po-wireless_provider').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-wireless_provider') else None),
                "Cellular Technology": get_text_or_none(soup.find('tr', class_='a-spacing-small po-cellular_technology').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-cellular_technology') else None),
                "Color": color,
                "Refresh Rate": get_text_or_none(soup.find('tr', class_='a-spacing-small po-refresh_rate').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-refresh_rate') else None),
                "SIM Count": get_text_or_none(soup.find('tr', class_='a-spacing-small po-sim_card_slot_count').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-sim_card_slot_count') else None),
                "Wireless Technology": get_text_or_none(soup.find('tr', class_='a-spacing-small po-wireless_network_technology').find('span', class_='a-size-base po-break-word') if soup.find('tr', class_='a-spacing-small po-wireless_network_technology') else None),
                "Price": price,
                "Price Before Promotion": get_text_or_none(soup.find('span', class_='a-price a-text-price').find('span', class_='a-offscreen') if soup.find('span', class_='a-price a-text-price') else None),
                "Rate": get_text_or_none(soup.find('span', class_='a-icon-alt')),
                "Camera": camera_info,
                "IMG": get_text_or_none(soup.find('img', class_='a-dynamic-image'), 'data-old-hires') or get_text_or_none(soup.find('img', class_='a-dynamic-image'), 'src'),
                "Website" : Website,
                'Currancy' : Currency,
                "URL" : link
            }
    
            # Extract reviews
            reviews_from_egypt = []
            reviews_outside_egypt = []
    
            review_elements = soup.find_all("div", class_="a-section review aok-relative")
            for review in review_elements:
                reviewer_name = get_text_or_none(review.find("span", class_="a-profile-name"))
                rating = get_text_or_none(review.find("span", class_="a-icon-alt"))
                review_date = get_text_or_none(review.find("span", class_="a-size-base a-color-secondary review-date"))
                review_text = get_text_or_none(review.find("span", class_="a-size-base review-text review-text-content"))
                
                review_info = f"Name: {reviewer_name}, Rating: {rating}, Date: {review_date}, Review: {review_text}"
                
                if "Verified Purchase" in review.text:
                    reviews_from_egypt.append(review_info)
                else:
                    reviews_outside_egypt.append(review_info)
    
            data["Reviews"] = reviews_from_egypt
            if data['Title']:
                print(f"Successfully scraped data for {data['Title']}")
                return data
            else:
                continue
                # print(f"No title found for {link}, retrying... (Attempt {attempt + 1}/{max_retries})")
        except Exception as e:
            continue
            # print(f"Error scraping {link}: {e}. Retrying... (Attempt {attempt + 1}/{max_retries})")
    
    print(f"Failed to scrape {link} after {max_retries} attempts")
    return None


# Main execution
    # Get all phone links with retries on individual pages
for proxy in proxies:
    proxy_failures[proxy['http']] = 0
with ThreadPoolExecutor(max_workers=10) as executor:
    executor.map(get_all_phones_link, all_phones_pages_link_list)

print(f"Total phone links found: {len(all_phones_link_list)}")

if len(all_phones_link_list) == 0:
    print("No phone links found. Exiting...")
else:
    # Scrape product data
    results = []
    with ThreadPoolExecutor(max_workers=50) as executor:
        future_to_url = {executor.submit(scrape_product_data, url): url for url in all_phones_link_list}
        for future in as_completed(future_to_url):
            url = future_to_url[future]
            try:
                data = future.result()
                if data:
                    results.append(data)
            except Exception as exc:
                print(f'{url} generated an exception: {exc}')
    
    print(f"Successfully scraped data for {len(results)} phones")
    
    df1 = pd.DataFrame(results)
    
    if not df1.empty:
        print("Data scraping and saving completed.")
    else:
        print("No data was scraped. Check the logs for errors.")
# Out:
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=7&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=1&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=6&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=4&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=8&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=9&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=10&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=5&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=2&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=3&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=11&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=14&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=12&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=13&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=15&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=17&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=18&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=19&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=20&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=16&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=22&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=21&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=25&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=24&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=23&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=26&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=27&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=28&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=30&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=31&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=32&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=29&language=en_AE
# Found 24 phones on page https://www.amazon.sa/s?i=electronics&rh=n%3A16966419031&fs=true&page=33&language=en_AE
# Total phone links found: 792
# Successfully scraped data for Apple iPhone 16 (128 GB) - Black
# Successfully scraped data for Apple iPhone 16 Pro (256 GB) - Desert Titanium
# Successfully scraped data for Tecno Spark Go 2024 Dual SIM Magic Skin Green 4GB RAM 128GB 4G - Middle East Version
# Successfully scraped data for Xiaomi Redmi 14C Dual SIM Starry Blue 8GB RAM 256GB 4G - Global Version
# Successfully scraped data for Coolpad CP12 Dual SIM Black 8GB RAM 128GB 4G LTE
# Successfully scraped data for OPPO Reno 12F 5G Dual SIM Amber Orange 12GB RAM 256GB - KSA Version With Gift Box
# Successfully scraped data for Xiaomi Redmi Pad Se Fhd+ Display 90Hz Refresh Rate, 6Nm Snapdragon 680, 8Gb Ram 256Gb Rom - Global Version 11 Inches Graphite Gray
# Successfully scraped data for SAMSUNG Galaxy M13 LTE Android Smartphone, 64 GB, 4 GB RAM, Dual Sim Mobile Phone, Orange Copper (KSA Version)
# Successfully scraped data for Apple iPhone 13 (128GB) - StarlightSuccessfully scraped data for Nothing Phone (2) 12+256, Glyph Interface, OS 2.0, 50MP dual camera, 6.7” LTPO AMOLED screen, 4700 mAh battery, waterproof, 5G Android smartphone, Dark Grey, Middle East Version
#
# Successfully scraped data for HONOR X9c 12GB RAM 256GB Dual SIM Titanium Black 5G With Free Gifts - Middle East Version
# Successfully scraped data for Apple iPhone X with FaceTime 256GB 4G LTE - Silver (Renewed)
# Successfully scraped data for نوت 40X الجيل الخامس 8+8 جيجابايت 256 ستارليت اسود بشريحتين
# Successfully scraped data for HUAWEI Pura 70 Smartphone, Dual SIM Mobile Phone, 12GB + 256GB, Flat-edge Screen, 50MP Ultra Lighting Camera, Durable Kunlun Glass, 66W SuperCharge, 4900mAh Battery, HUAWEI Care+, Black (KSA Version)
# Successfully scraped data for OnePlus 12 5G | Unlocked Dual SIM (Flowy Emerald, 16 GB RAM, 512GB)
# Successfully scraped data for Nokia 105 [2017] TA-1037 Dual-Band (850/1900) Factory Unlocked Mobile Phone - Black
# Successfully scraped data for MOTOROLA EDGE 50 ULTRA XT2401-1 1TB GB+16GB DS 5G ARABIC NORDIC WOOD,Snapdragon® 8s Gen 3,50MP, 6.7" OLED, 4500mAh, Android 14
# Successfully scraped data for Samsung Galaxy A15 LTE, Android Smartphone, Dual SIM Mobile Phone, 6GB RAM, 128GB Storage, Blue Black (UAE Version)
# Successfully scraped data for OPPO Reno 12F 5G Dual SIM Olive Green 12GB RAM 256GB - KSA Version With Gift Box
# Successfully scraped data for NOKIA 215 4G 2024, DS, BLACK
# Successfully scraped data for Apple iPhone 16 Pro Max (256 GB) - Desert Titanium
# Successfully scraped data for Infinix Smart 9 (RAM: 4+4GB, ROM: 128GB), 6.7" HD+ Display, 13MP Dual AI Rear Camera With Flashlight, 8MP Front Camera, 5000 mAh Battery, Dual Nano Sim, Type-C, Android 14 - Neo Titanium Color
# Successfully scraped data for Samsung Galaxy Z Fold6, AI Phone, 12GB RAM, 256GB Storage, Silver Shadow, Android Smartphone, 50MP Camera, Big Screen, Multi-tasking, S Pen, Long Battery Life (KSA Version)
# Successfully scraped data for HONOR X9c 12GB RAM 256GB Dual SIM Jade Cyan 5G - Middle East Version
# Successfully scraped data for SAMSUNG Galaxy S24 Ultra, AI Phone, 256GB Storage, Titanium Gray, 12GB RAM, Android Smartphone, 200MP Camera, S Pen, Long Battery Life (KSA Version).
# Successfully scraped data for HONOR X8b Smartphone 4G Midnight Black, 16GB(8+8)RAM 512GB ROM, 108MP Main Camera + 50MP Selfie Camera, 90Hz Super AMOLED Display, 4500mAh Battery, 35W SuperCharge, 6nm Snapdragon Chipset, Android 13
# Successfully scraped data for realme Note 50 Dual-SIM 64GB ROM + 3GB RAM 4G (Sky Blue)
# Successfully scraped data for Samsung Galaxy A16 5G, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 128GB Storage, Blue Black (KSA Version)
# Successfully scraped data for Samsung Galaxy A35 5G, 128GB Storage, 8GB RAM, Android Smartphone, Awesome Navy (KSA Version)
# Successfully scraped data for MOTOROLA G35 5G, 8+16GB RAM,pSIM + eSIM,128 GB ROM, UNISOC T760, 6.7" pOLED Display 120Hz, Android 14, Leaf Green
# Successfully scraped data for Apple iPhone 12 (128GB) - Black (Renewed)
# Successfully scraped data for realme Note 60 4G Android Smartphone, 32MP Main Camera, 4GB RAM 128GB ROM, Dual SIM, Up to 2TB External Memory with SD Card, 5000mAh Battery, 6.74" LCD Display, Marble Black
# Successfully scraped data for HONOR 200 5G Dual SIM 12GB RAM + 256GB Emerald Green With Free GIFTS - Middle East Version
# Successfully scraped data for Nokia 5310 Series 30+ Phone with Wireless FM Radio and 16 Mb Ram (White/Red)
# Successfully scraped data for Apple iPhone 12 Pro Max (256GB) - Pacific Blue (Renewed)
# Successfully scraped data for Nokia 106 TA-1564 DS NENA1 Dual SIM 48MB Ram+128MB ROM (1.8 Inches) (2G) - (Charcoal)
# Successfully scraped data for VIVO Y19s 4G Dual SIM Pearl Silver 6GB RAM 128GB with Diary and Bottle and 2 Years Warranty - Middle East Version
# Successfully scraped data for SAMSUNG Galaxy S24+, AI Phone, 256GB Storage, Onyx Black, 12GB RAM, Android Smartphone, 50MP Camera, Bigger Display, Faster RAM, Long Battery Life (KSA Version)
# Successfully scraped data for Infinix Smart 8 (RAM: 3+3GB, ROM: 64GB), 6.6" HD+ Display, 13MP Dual AI Rear Camera With Ring Flashlight, 8MP Front Camera, 5000 mAh Battery, Dual Nano Sim, Type-C, Android 13 - Timber Black Color
# Successfully scraped data for Samsung Galaxy A55 5G, 256GB Storage, 8GB RAM, Android Smartphone, Awesome Navy (KSA Version)
# Successfully scraped data for Infinix Note40 5G 8+8 GB 256 GB Obsidian Black
# Successfully scraped data for Xiaomi POCO F6 Black 12GB 512GB 5G - Global Version
# Successfully scraped data for Samsung Galaxy A25 5G, Android Smartphone, Dual SIM Mobile Phone, 6GB RAM, 128GB Storage, Blue Black (KSA Version)
# Successfully scraped data for Infinix GT20 Pro 5G, RAM (12+12GB), ROM (256GB), 144Hz FHD+ AMOLED Display, 108MP Rear AI Camera, 5000mAh Battery With 45W Fast Charging, Mecha Loop LED, NFC - Mecha Blue Color
# Successfully scraped data for Apple iPhone 14 Pro Max 5G 256GB - Deep Purple (Renewed)
# Successfully scraped data for Xiaomi Redmi A3 Dual SIM Forest Green 3GB RAM 64GB 4G - KSA Version
# Successfully scraped data for motorola ThinkPhone 5G , DUAL-SIM 8GB+8GB RAM, 256GB Carbon black
# Successfully scraped data for HONOR X7c Dual SIM 8 GB RAM 256GB Forest Green 4G - Middle East Version
# Successfully scraped data for HONOR X7c Dual SIM 8GB RAM 256GB Moonlight White 4G - Middle East Version
# Successfully scraped data for Samsung Galaxy A06 LTE, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 64GB Storage, Black
# Successfully scraped data for Xiaomi Redmi Pad SE (Graphite Gray 8GB RAM, 256 Storage) - 11Inch FHD+ eye-care display |6nm Snapdragon 680 Mobile Platform | Smooth 90Hz refresh rate | Quad speakers with Dolby Atmos
# Successfully scraped data for realme C61 Dual SIM Mobile Phone Sparkle Gold 8GB RAM + 16GB Extended RAM 256GB ROM 6.74 inch Screen 4G Smartphone, 5000 MAh Battery 50MP Main Camera- Middle East Version
# Successfully scraped data for HONOR X9b 5G 12GB+256GB Midnight Black
# Successfully scraped data for Infinix Hot50Pro+ 16GB* 256 GB Sleek Black + Ai Support
# Successfully scraped data for Xiaomi Redmi A3 Dual SIM Midnight Black 4GB RAM 128GB 4G - KSA Version
# Successfully scraped data for vivo V40 5G (Nebula Purple, 12GB RAM, 256GB) | 3D Curved AMOLED 120Hz Display | 50MP ZEISS Camera | 5500 mAh BlueVolt Battery | IP69 – Middle East Version
# Successfully scraped data for OPPO A60 5G Dual SIM Nebula Red 6GB RAM 128GB - KSA Version
# Successfully scraped data for Xiaomi POCO X6 Pro 5G Dual Sim Black 12GB RAM 512GB 5G - Global Version
# Successfully scraped data for Samsung Galaxy S21 FE 5G 2nd Generation Smartphone Smartphone 8GB RAM 128GB Memory Snapdragon 888 Processor Green
# Successfully scraped data for MOTOROLA G04S XT2421-9 128GB+4GB DS 4G ARABIC SATIN BLUE
# Successfully scraped data for Samsung Galaxy A06 128GB Black, KSA Version
# Successfully scraped data for Xiaomi POCO M6 Pro Dual Sim Black 12GB RAM 512GB 4G + Screen Protection Card - Global Version
# Successfully scraped data for itel A70 Smartphone | 4+8GB RAM, 256GB Storage | 8MP AI Selfie Camera | 5000mAh Battery | Type-C Charging | Dynamic Bar | Starlish Black
# Successfully scraped data for Xiaomi Redmi Note 13 Pro (Midnight Black 8GB RAM, 256 Storage) - Ultra-clear 200MP camera with OIS |120Hz FHD+AMOLED display | Immersive viewing with ultra-thin bezels
# Successfully scraped data for SAMSUNG Galaxy M12 Dual SIM Smartphone - 64GB, 4GB RAM, 4G LTE, Green (KSA Version)
# Successfully scraped data for vivo V40 Lite 5G (Dynamic Black, 12GB RAM, 256GB) | 120Hz AMOLED Display | 32MP Selfie Camera | 5000Ah Battery | IP64 | TWS, 24M Warranty, 12M Broken Screen Replacement – Middle East Version
# Successfully scraped data for Redmi 12 5G Dual SIM Sky Blue 8GB RAM 256GB - Global Version
# Successfully scraped data for VIVO Y19s 4G Dual SIM Glossy Black 6GB RAM 128GB and 2 Years Warranty - Middle East Version
# Successfully scraped data for MOTOROLA G04S XT2421-9 128GB+4GB DS 4G ARABIC SEA GREEN
# Successfully scraped data for nubia V60 Design (6GB RAM + 256GB ROM), Additional 10GB Dynamic RAM, 6.6 HD+ Display, 50MP AI Rear Camera, 8MP Front Camera, 5000mAh Battery With 22.5W Fast Charging, NFC - Dark Blue Color
# Successfully scraped data for Samsung Galaxy S24 FE, AI Phone, Android Smartphone, 8GB RAM, 256GB Storage, 50MP Camera, Long Battery Life, Large Screen, Graphite (KSA Version)
# Successfully scraped data for Xiaomi POCO F6 5G Mobile, Titanium (8GB Ram+256GB) | Snapdragon 8s Gen 3| 6.67" AMOLED 120Hz display | Triple Camera with OIS 50+8MP, 20MP Front camera
# Successfully scraped data for Infinix Hot50i (RAM: 4+4GB, ROM: 128GB), 6.7" HD+ Display, 48MP Dual AI Rear Camera, 8MP Front Camera, 120Hz Display, 5000 mAh Battery, Dual Nano Sim, Type-C, Android 14 - Titanium Grey, NFCSuccessfully scraped data for TECNO Spark 30 5G, 8GB+256GB| 108MP Main Camera with Dolby Atmos Speakers | MediaTek D6300 5G Processor | 6.67" 120Hz HD+ Hole LCD Display | 6000mAh Battery with 18W Charger (Midnight Shadow)
#
# Successfully scraped data for Samsung Galaxy A55 5G, 256GB Storage, 8GB RAM, Android Smartphone, Awesome Lemon (KSA Version)
# Successfully scraped data for Apple iPhone 11 Pro Max with Facetime - 256GB, 4G LTE, Midnight Green, Middle East Version (Renewed)
# Successfully scraped data for HONOR X6b 6GB+256GB Midnight Black with Free gift
# Successfully scraped data for Apple iPhone 11 (128GB) - White (Renewed)
# Successfully scraped data for Xiaomi POCO C65 Dual SIM Blue 8GB RAM 256GB 4G - Global Version
# Successfully scraped data for SAMSUNG Galaxy S24, AI Phone, 256GB Storage, Onyx Black, 8GB RAM, Android Smartphone, 50MP Camera, Long Battery Life (KSA Version)
# Successfully scraped data for Xiaomi 14T Pro Dual SIM+eSIM Titan Black 12GB RAM 512GB 5G - Global Version
# Successfully scraped data for Honor Magic6 Pro 5G - 12 GB RAM, 512 GB - Epi Green| Honor Service Care+
# Successfully scraped data for MOTOROLA Edge 50 5G, 12GB RAM, 512 GB ROM, Snapdragon 7 Gen 1, 6.67" pOLED Display 120Hz, Android 14, Koala Grey
# Successfully scraped data for MOTOROLA G04S XT2421-9 128GB+4GB DS 4G ARABIC SUNRISE ORANGE
# Successfully scraped data for Nokia 105 EG TA-1459 DS (Charcoal)
# Successfully scraped data for Xiaomi POCO X6 5G Dual Sim Black 12GB RAM 256GB 5G - Global Version
# Successfully scraped data for MOTOROLA moto g14 4G Dual Sim, 4GB+128GB, FHD+ HiD 60Hz, 50MP Camera, Butter Cream
# Successfully scraped data for Samsung Galaxy A35 5G, 128GB Storage, 8GB RAM, Android Smartphone, Awesome Lemon (KSA Version)
# Successfully scraped data for Infinix Zero 40 5G 12+12 GB 256 GB Rock Black
# Successfully scraped data for Samsung Galaxy A55 5G, 128GB Storage, 8GB RAM, Android Smartphone, Awesome Lemon (KSA Version)
# Successfully scraped data for vivo Y03 4G Dual SIM Gem Green 4GB RAM 128GB 5000Mah - Middle East Version
# Successfully scraped data for Honor X7b Dual SIM Midnight Black 8GB RAM+256GB 5G
# Successfully scraped data for HONOR X6b 6GB+256GB Forest Green
# Successfully scraped data for NOTHING PHONE (1), SNAPDRAGON, 6.55" OLED, 8GB, 256GB, DUAL SIM, 5G, 50 MP CAM, GLUPH, SMARTPHONE BLACK
# Successfully scraped data for Xiaomi 14T Dual SIM+eSIM Titan Gray 12GB RAM 256GB 5G - Global Version
# Successfully scraped data for MOTOROLA G85 5G, 12GB+12GB RAM, 256 GB ROM, Snapdragon 695 5G, 6.67" pOLED Display 120Hz, Android 14, Cobalt Blue
# Successfully scraped data for Samsung Galaxy A35 5G, 256GB Storage, 8GB RAM, Android Smartphone, Awesome Lilac (KSA Version)
# Successfully scraped data for Samsung Galaxy A73 5G Android Smartphone 256 GB, 8 GB RAM, Dual Sim Mobile Phone, Awesome Mint (UAE Version)
# Successfully scraped data for OPPO Reno 12 5G Dual SIM Astro Silver 12GB RAM 512GB - KSA Version With Gift Box And Car Charger
# Successfully scraped data for OPPO A60 5G Dual SIM Nebula Red 6GB RAM 256GB - KSA Version With Gift Bluetooth Earphones O Choice
# Successfully scraped data for vivo V30e 5G (Green, 12+12GB RAM, 256GB) | 50 MP Sony IMX Camera | 5500mAh, 44W Charger | 120 Hz | | NFC | Online Exclusive Model | Gifts: Fitness Band, TWS, 24M Warranty and 12M Screen Protection
# Successfully scraped data for SAMSUNG Galaxy S22 Ultra Dual SIM Burgundy 12GB RAM 256GB 5G - International Version
# Successfully scraped data for Apple iPhone 13 Pro (256GB) - Sierra Blue (Renewed)
# Successfully scraped data for Apple iPhone 12 Pro (128GB) - Pacific Blue (Renewed)
# Successfully scraped data for SAMSUNG B310 Piton (White)
# Successfully scraped data for Honor 90 Lite Dual-SIM 256GB ROM + 8GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Cyan Lake) - International Version
# Successfully scraped data for SAMSUNG SM-B310E (Dual SIM, Black)
# Successfully scraped data for Samsung Galaxy A23 - Dual SIM, 6GB RAM, 128GB Storage, Android Smartphone, 4G - Black - 1 year Warranty
# Successfully scraped data for HONOR X9b 5G 12GB+256GB Emerald Green + HONOR CHOICE Earbuds X5 + HONOR VIP Care+
# Successfully scraped data for vivo V40 Lite 5G (Dynamic Black, 12GB RAM, 256GB) | 120Hz AMOLED Display | 32MP Selfie Camera | 5000Ah Battery | IP64 – Middle East Version
# Successfully scraped data for Tecno Camon 30 5G Dual SIM Dolby Atmos Speaker Smartphone,12GB RAM 512GB ROM | 50MP Rear,50MP Front Camera |120Hz 6.78'' FHD+ AMOLED Screen | 5000mAh| 70W Type-C, Android 14 (Basaltic Dark)
# Successfully scraped data for realme C63 Mobile Phone, Dual SIM 6+6GB RAM 128GB 4G Smartphone, 45W Fast Charge, 5000mAh Massive Battery, 50MP AI Camera, Middle East Version,Jade Green
# Successfully scraped data for Nubia Z2353 Nubia Music 4GB RAM 128GB Storage 5200mAh Battery 50MP Camera 6.6-Inch Display Smartphone, POP Art
# Successfully scraped data for realme C65 Unlocked Dual-SIM Android Smart Phone, 6.67" Eye Comfort Display, 8GB RAM 256GB ROM, 5000 mAh Battery, 50MP AI Camera, 45W Fast Charge, Starlight Gold, Middle East Version
# Successfully scraped data for Nokia 105 2019 KING TA-1174 DS FR BLACK
# Successfully scraped data for OPPO A3X Dual SIM Nebula Red 4GB RAM 128GB 4G LTE - KSA Version With Earphones
# Successfully scraped data for Samsung Galaxy A16, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 128GB Storage, Gray (KSA Version)
# Successfully scraped data for VIVO Y28s 5G Dual SIM Twinkling Purple - 8GB RAM | 256GB Storage | 6.56" HD Display | 50MP Camera | 5000mAh Battery | IP64 Water & Dust Resistant - Middle East Version
# Successfully scraped data for Xiaomi Redmi 12 (Midnight Black 8GB RAM, 128 Storage) - MediaTek G88 Powerful Processor |50MP High-Resolution main camera | 90 Hz FHD+ AdaptiveSync display | 5000mAh(Typ) High-Capacity battery
# Successfully scraped data for Apple iPhone 11 Pro Max with FaceTime (256GB) - Gold (Renewed)
# Successfully scraped data for Realme 12 Pro 5G Dual SIM 8GB RAM + 256GB (Navigator Beige)
# Successfully scraped data for OnePlus Nord CE4 Lite 5G (Super Silver, 8GB RAM, 256GB Storage)
# Successfully scraped data for Xiaomi Redmi 14C Dual SIM Midnight Black 8GB RAM 256GB 4G - Global Version
# Successfully scraped data for vivo V40 Lite 5G (Titanium Silver, 12GB RAM, 512GB) | 120Hz AMOLED Display | 32MP Selfie Camera | 5000Ah Battery | IP64 – Middle East Version
#
# Successfully scraped data for HONOR X9b 5G 12GB RAM + 256GB ROM, Dual Sim, 120Hz Curved AMOLED Display, 5800 mAh Battery, 108MP Triple Camera, Emerald Green - UAE TRA Version
# Successfully scraped data for Samsung Galaxy S22 Ultra 5G Mobile Phone 128GB SIM Free Android Smartphone Phantom Black- International Version
# Successfully scraped data for Apple iPhone 13 Pro Max (256GB) - Graphite (Renewed)
# Successfully scraped data for MOTOROLA G35 5G, 8+16GB RAM,pSIM + eSIM,128 GB ROM, UNISOC T760, 6.7" pOLED Display 120Hz, Android 14, Midnight Black
# Successfully scraped data for Apple iPhone 16 Plus (256 GB) - Teal
# Successfully scraped data for Apple iPhone 14 (128 GB) - Midnight
# Successfully scraped data for Apple iPhone 11 Pro with FaceTime (256GB) - Midnight Green (Renewed)
# Successfully scraped data for ITEL A50 3+64GB - Misty Black
# Successfully scraped data for vivo Y28s 5G Dual SIM Mocha Brown - 8GB RAM | 256GB Storage | 6.56" HD Display | 50MP Camera | 5000mAh Battery | IP64 Water & Dust Resistant - Middle East Version
# Successfully scraped data for Xiaomi Redmi Note 13 5G Dual Sim Ocean Teal 8GB RAM 256GB 5G - Global Version,Blue
# Successfully scraped data for Apple iPhone 15 (128 GB) - Blue
# Successfully scraped data for HONOR 200 LITE 8 GB RAM, 256 GB Dual NANO SIM 5G AI Empowered Magic Portal - Cyan Blue | HONOR Service Care+
# Successfully scraped data for Samsung Galaxy A55 5G, 128GB Storage, 8GB RAM, Android Smartphone, Awesome Iceblue (KSA Version)
# Successfully scraped data for Xiaomi Redmi Note 13 Pro 5G Dual Sim Ocean Teal 12GB RAM 512GB 5G - Global Version
# Successfully scraped data for MOTOROLA G85 5G, 12GB+12GB RAM, 256 GB ROM, Snapdragon 695 5G, 6.67" pOLED Display 120Hz, Android 14, Olive Green
# Successfully scraped data for MOTOROLA G35 5G, 8+16GB RAM,pSIM + eSIM,128 GB ROM, UNISOC T760, 6.7" pOLED Display 120Hz, Android 14, Guava Red
# Successfully scraped data for MOTOROLA E14 XT2421-14 64GB+2GB DS 4G ARABIC PASTEL PURPLE
# Successfully scraped data for Tecno Spark Go 2024 Dual SIM Magic Skin Green 4GB RAM 64GB 4G - Middle East Version
# Successfully scraped data for Infinix Hot 50 (RAM: 6+6GB, ROM: 256GB), 6.78" FHD+ Display, 50MP Triple AI Rear Camera With Flashlight, 8MP Front Camera, 5000 mAh Battery, Dual Nano Sim, Type-C, Android 14 -Titanium Grey, NFC
# Successfully scraped data for OALE A10 Android Smartphone 5.5 inch screen 16GB + 1GB HD Camera 3050mAh battery DUAL SIM 3G Black
# Successfully scraped data for Nubia Neo 5G, 8+256GB, Phantom Black, Up to 18GB RAM*, Powerful 5G SoC, 120HZ Ultra-Smooth Display, Built for Gamers
# Successfully scraped data for Samsung Galaxy S23 Ultra, 512GB, Green, 5G Mobile Phone, Dual SIM, Android Smartphone (KSA Version)
# Successfully scraped data for Samsung Galaxy A06 LTE, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 64GB Storage, Light Blue (UAE Version)
# Successfully scraped data for Nubia Neo 5G, 8+256GB, War-damaged Yellow, Up to 18GB RAM*, Powerful 5G SoC, 120HZ Ultra-Smooth Display, Built for Gamers
# Successfully scraped data for HONOR X5b Plus Dual SIM 8GB(4+4) RAM 128GB Midnight Black 4G - Middle East Version
# Successfully scraped data for Tecno Spark Go 2024 64+2 Dual SIM 4G Android Smartphone |Segment First 90Hz Dot-in Bigger Display With Dual DTS Speakers | 5000mAh| 10W Type-C| Fingerprint Sensor- KSA Version (Gravity Black)
# Successfully scraped data for Apple iPhone 15 Plus (128 GB) - Black
# Successfully scraped data for MOTOROLA G85 5G, 12GB+12GB RAM, 256 GB ROM, Snapdragon 695 5G, 6.67" pOLED Display 120Hz, Android 14, Urban Grey
# Successfully scraped data for Honor X7b Smartphone 4G, 8GB Turbo RAM + 256GB Storage, 108MP Triple Camera, 6.8 Inch 90Hz Display, 6000mAh Battery, 35W Super Charge, 6nm Snapdragon Processor, Dual SIM, Android 13, Emerald Green
# Successfully scraped data for Nokia Dreamzon 150 Dual SIM 4G
# Successfully scraped data for Nokia 105 Single SIM, Keypad Mobile Phone with Wireless FM Radio | Blue
# Successfully scraped data for Xiaomi Redmi A3 Dual SIM Star Blue 3GB RAM 64GB 4G - KSA Version
# Successfully scraped data for Xiaomi Redmi Note 13 (Ice Blue 8GB RAM, 256 Storage) - Super-clear 108MP triple camera |120Hz FHD+AMOLED display | Immersive viewing with ultra-thin bezels | Secure in-screen fingerprint sensor
# Successfully scraped data for CMF by Nothing Phone 1, 8/256 GB, 6.67" AMOLED Screen, MediaTek 7300 Processor, 5000mAh, Rear Cam 50+2MP, Front Cam 16MP, Dual Sim 5G, Extendable Memory upto 2 TB, Black, Middle East Version
# Successfully scraped data for HONOR 200 LITE 8 GB RAM, 256 GB Dual NANO SIM 5G AI Empowered Magic Portal - Starry Blue | HONOR Service Care+
# Successfully scraped data for Xiaomi Redmi Note 13 Pro+ 5G Dual Sim Midnight Black 12GB RAM 512GB 5G - Global Version
# Successfully scraped data for MOTOROLA Edge 50 Fusion 5G, RAM 12GB Expandable up to 24GB, ROM 512GB, 6.67" PoLED FHD+ 120Hz 3D Curved Display, Rear Camera 50MP+13MP, Front Camera 32MP, 5000mAh, 68W Turbo Charging-Marshmallow Blue
# Successfully scraped data for NOKIA 230 DUAL SIM WITH FRONT CAMERA
# Successfully scraped data for MOTOROLA Edge 50 Fusion 5G, RAM : 12GB Expandable up to 24GB, ROM : 512GB, 6.67" PoLED FHD+ 120Hz 3D Curved Display, Rear Camera 50MP+13MP, Front Camera 32MP, 5000mAh, 68W Turbo Charging - Forest Blue
# Successfully scraped data for realme Note 50 Unlocked Dual-SIM Android Smart Phone, 6.74" LCD 90Hz Vivid Display, 4GB RAM 128GB ROM, 5000 mAh Battery, 13MP AI Camera, Midnight Black，Middle East Version
# Successfully scraped data for Samsung Galaxy S23 FE 5G Dual SIM Android Smartphone, 8GB RAM, 256GB Storage, Mint (KSA Version)
# Successfully scraped data for ONEPLUS Nord N30 SE Dual SIM 4GB RAM 128GB 5G- Green Cyan Sparkle Middle East Version
# Successfully scraped data for SAMSUNG Galaxy A13 5G Android Smartphone, 64 GB, 4 GB RAM, Dual Sim Mobile Phone, Black (KSA Version)
# Successfully scraped data for Nokia 230 Dual-SIM 16MB (GSM Only | No CDMA) Factory Unlocked 2G Cell Phone (Dark Silver) - International Version
# Successfully scraped data for Nokia هاتف خلوي من نوكيا 150 4G شريحة واحدة ازرق
# Successfully scraped data for Xiaomi Redmi 10A Graphite Gray 2GB Ram 32GB Rom
# Successfully scraped data for Apple iPhone 12 Pro (128GB) - Gold (Renewed)
# Successfully scraped data for Samsung Galaxy A04, 32GB, 3GB RAM, Dual SIM, Copper (KSA Version)
# Successfully scraped data for realme C67 Dual-SIM 128GB ROM + 6GB RAM 4G (Sunny Oasis)
# Successfully scraped data for OPPO A16K CPH2349 64GB+4GB DS 4G ARABIC BLACK
# Successfully scraped data for OPPO A60 5G Dual SIM Ocean Blue 6GB RAM 256GB - KSA Version With Gift Bluetooth Earphones O Choice
# Successfully scraped data for New Apple Iphone Se (128 Gb) - Starlight (3rd Gen)
# Successfully scraped data for Sony Xperia 1 VI DUAL-SIM 12GB RAM 256GB 5G (Black)
# Successfully scraped data for Itel P55 Dual SIM Aurora Blue 8+16GB RAM 256GB 4G - Middle East Version
# Successfully scraped data for Google Pixel 9 5G 2024 (GUR25 | International Version) 6.3-inch Dual-SIM (nano-SIM, eSIM), Unlocked Android 14 Smartphone (128GB Storage + 12GB RAM, Obsidian)
# Successfully scraped data for Google Pixel 9 Pro XL 5G 2024 (GZC4K | International Version) Dual-SIM (nano-SIM, eSIM), Unlocked Android 14 Smartphone (256GB Storage + 16GB RAM, Hazel)
# Successfully scraped data for HUAWEI nova 12i Smart Phone, Dual SIM Mobile Phone, 6.7-inch AOD Display, 40 W Turbo, 5000 mAh Durable Battery, 108 MP High-Res Photography, 8 + 256GB Storage, EMUI 14, LTE, Green
# Successfully scraped data for Xiaomi Redmi Note 13 (Ocean Sunset 8GB RAM, 256 Storage) - Super-clear 108MP triple camera |120Hz FHD+AMOLED display | Immersive viewing with ultra-thin bezels | Secure in-screen fingerprint sensor
# Successfully scraped data for Xiaomi Redmi A3 Dual SIM Forest Green 4GB RAM 128GB 4G - KSA Version
# Successfully scraped data for vivo V40 Lite 5G (Titanium Silver, 12GB RAM, 256GB) | 120Hz AMOLED Display | 32MP Selfie Camera | 5000Ah Battery | IP64 | TWS, 24M Warranty, 12M Broken Screen Replacement – Middle East Version
# Successfully scraped data for MOTOROLA Razr 50 5G, 8GB+8GB RAM, 256 GB ROM, MediaTek Dimensity 7300X, 6.9 + 3.6" pOLED Display, Android 14, Koala Grey
# Successfully scraped data for OnePlus Nord CE 3 5G -CPH2569 (12GB + 256GB, Aqua Surge)
# Successfully scraped data for vivo V40 Lite 5G (Dynamic Black, 12GB RAM, 512GB) | 120Hz AMOLED Display | 32MP Selfie Camera | 5000Ah Battery | IP64 – Middle East Version
# Successfully scraped data for Tecno Spark 20C 4/256Gb Bg7N Gravity 265 Gb Black
# Successfully scraped data for Oppo A79 5G Dual-SIM 128GB ROM + 4GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Mystery Black) - International Version
# Successfully scraped data for Samsung Galaxy A16, Android Smartphone, Dual SIM Mobile Phone, 4GB RAM, 128GB Storage, Black (KSA Version)
# Successfully scraped data for Apple iPhone 14 Pro Max (256 GB) - Gold (Renewed)
# Successfully scraped data for OnePlus Nord CE 3 Lite 5G Dual-SIM 128GB ROM + 8GB RAM (GSM only | No CDMA) Factory Unlocked 5G SmartPhone (Chromatic Gray) - International Version
# Successfully scraped data for Samsung Galaxy A05s, Android Smartphone, Dual SIM Mobile Phone, LTE, 6GB RAM, 128GB Storage, Silver (UAE Version)
# Successfully scraped data for Redmi 13 Mobile, Sandy Gold (8GB Ram+256GB) |Mediatek helio G91 ultra processor| 6.79" FHD+ 90Hz display | Triple Camera 108MP + 2MP, 13MP Front camera | 3-pin charger | 1 year manufacturer warranty
# Successfully scraped data for HONOR 90 5G 12GB RAM 512GB Diamond Silver - Middle East Version
# Successfully scraped data for Samsung Galaxy A35 5G, 256GB Storage, 8GB RAM, Android Smartphone, Awesome Lemon (KSA Version)
# Successfully scraped data for Nokia 6310 (2021) Dual-SIM 8MB ROM + 16MB RAM (GSM Only | No CDMA) Factory Unlocked 2G/LTE Cellphone (Dark Green) - International Version
# Successfully scraped data for Samsung Galaxy Note20 Dual SIM 256GB 8GB RAM 5G - Mystic Bronze
# Successfully scraped data for OPPO A77s Dual SIM 6.56 inches Smartphone 128GB 8GB RAM|5000mAh Long Lasting Battery |Fingerprint and Face Recognition | 4G LTE Android Phone, Sunset Orange
# Successfully scraped data for Google هاتف خلوي من جوجل بكسل 8 ايه ازرق
# Successfully scraped data for Tecno Spark Go 2024 Dual SIM Magic Skin Green 3GB RAM 64GB 4G - Middle East Version
# Successfully scraped data for MOTOROLA g24, 8GB+8GB RAM, 128GB ROM, MTK Helio G85, 6.6" Extra Bright 90Hz Display, 5000mAh, Android 14, Matte Charcoal
# Successfully scraped data for HONOR 200 Lite 5G 16GB(8+8GB) RAM + 256GB Dual SIM Cyan Lake - UAE Version
# Successfully scraped data for HUAWEI Nova Y90 Smart Phone (+ Free NeckBand), 6.7" Edgeless FullView Display, 40W Fast Charging, 5000 mAh Large Battery, 50 MP AI Triple Camera, 6GB RAM, 128GB Storage, EMUI 12, LTE, Emerald Green
# Successfully scraped data for Skyshop® LBSTAR BM10 World's Smallest Mobile Phone Dual Sim Support with Bluetooth Dialer (Grey)
# Successfully scraped data for Xiaomi POCO F6 5G Mobile, Black (8GB Ram+256GB) | Snapdragon 8s Gen 3| 6.67" AMOLED 120Hz display | Triple Camera with OIS 50+8MP, 20MP Front camera
# Successfully scraped data for HONOR X6a 4GB RAM 128GB 4G LTE Sky Silver
# ...
# Successfully scraped data for Honor 90 Lite Dual-SIM 256GB ROM + 8GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Midnight Black) - International Version
# Successfully scraped data for HUAWEI P50 Smart Phone,6.5 inches,256GB+8GB 300 Hz Touch Sampling Rate,Dual-Matrix Camera Design,66W Charge,4G Smooth and Fast Intelligent Cross-Device Collaboration,Golden Black
# Successfully scraped data for OPPO Reno10 Pro+ 5G 256GB 12GB Silvery Grey + Free Air 2 pro earbuds + Bluetooth Speaker + 12 months extended warranty
# Successfully scraped data for Honor X7 Dual SIM Ocean Blue 6GB RAM 128GB 4G LTE
# Successfully scraped data for LYTFGHJ Small Cell Phone, 2.5 Inch Screen Mini Smartphone for Communication(Green)
# Successfully scraped data for QIeCny Backup Machine for The Elderly/children, Unlocked Flip Cell Phone, 2.4"/1.44" Dual Screen, Dual Sim Card, Multimedia Mp3, 2800 MAh Battery, Large Keypad+Large Volume, With SOS Button,Red
# Successfully scraped data for Nokia C Series C5-00 5MP Camera (Unlocked) Smartphone Nokia C5-00- Gray Color
# Successfully scraped data for Tecno Spark 20 Dual SIM Cyber White 8GB RAM 128GB 4G - Middle East Version
# Successfully scraped data for VITURE One Neckband, Compatible One XR Glasses, Official Partner of PSPlay & XBXPlay, 128GB, Remote Play, Cloud Gaming, Stream on Game Consoles, Bluetooth (Matte Blue)
# Successfully scraped data for Tecno Spark 30C 5G Dual SIM Android 14 Smartphone | 48MP Ultra Clear Camera |120Hz 6.67'' HD+ Hole Screen With Dolby Atmos Speakers | 5000mAh| 18W Type-C (Midnight Shadow)
# Successfully scraped data for HUAWEI Pura 70 Ultra Smartphone, 6.8" HD OLED display, Pop-out Camera, Ultra Speed Snapshot, 100W SuperCharge, 16GB+512GB, Brown + 'HUAWEI Freebuds PRO3'
# Successfully scraped data for Oneplus nord n10 5g 6gb 128gb smartphone 6.49 inch screen 90hz display, snapdragon 690, dual sim gsm unlocked, 64mp quad camera, nfc, global version, midnight ice
# Successfully scraped data for Nokia 6288 Unlocked Cell Phone with 2 MP Camera, Black
# Successfully scraped data for NOKIA 110 Feature Phone, Dual SIM, 4 MB RAM, Camera - Black
# Successfully scraped data for Realme GT Neo 3 150W Dual-SIM 256GB ROM + 12GB RAM (GSM Only | No CDMA) Factory Unlocked 5G Smartphone (Asphalt Black) - International Version
# Successfully scraped data for Realme GT2 Dual-SIM 128GB ROM + 8GB RAM (GSM | CDMA) Factory Unlocked 5G SmartPhone (Paper White) - International Version
# Successfully scraped data for Samsung Galaxy S21 5G G9910 256GB 8GB RAM International Version - Phantom Gray
# Successfully scraped data for Xiaomi Redmi Note 11 Dual Sim Graphite Gray 6Gb Ram 128Gb 4G Lte 90Hz Amoled 33W Pro Fast Charging 50Mp Ai Quad Camera
# Successfully scraped data for Apple iPhone 13 (128GB) - Midnight (Renewed)
# Successfully scraped data for TTfone TT970 Whatsapp 4G Touchscreen Senior Big Button Flip Mobile Phone Easy and Simple to Use Bundle Deal, TT970Bundle,
# Successfully scraped data for OPPO A54s Dual Sim 128GB ROM 4GB RAM 4G (Crystal Black) - International Version
# Successfully scraped data for Google Pixel 9 Pro 5G 2024 (GEC77 | International Version) 6.3-inch Dual-SIM (nano-SIM, eSIM), Unlocked Android 14 Smartphone (128GB Storage + 16GB RAM, Obsidian)
# Successfully scraped data for New Apple Watch Series 9 [GPS + Cellular 41mm] Smartwatch with Graphite Stainless steel Case with Graphite Milanese Loop One Size. Fitness Tracker, Blood Oxygen & ECG Apps, Water Resistant
# Successfully scraped data for Nokia 1.4 Android Smartphone Dual Sim, 3Gb Ram, 64 Gb Memory, 6.51"Hd+Edge-To-Edge Screen, Face Unlock, Finger Print – Blue
# Successfully scraped data for Honor X7a Dual SIM 6GB RAM 128GB 4G LTE Midnight Black
# Successfully scraped data for Tecno Spark 20C Dual SIM Magic Skin Green 4GB RAM 128GB 4G - Middle East Version
# Successfully scraped data for CUBOT KINGKONG 8 Rugged Smartphone 6.528'' HD+ Screen, 6GB RAM,256GB ROM, Dual LED Torch,Dual SIM, 10600mAh Battery, Android 13 Rugged Cell Phone 16MP Front+48MP Rear Camera NCF
# Successfully scraped data for Tecno Spark 20 Dual SIM Cyber White 8GB RAM 256GB 4G - Middle East Version
# Successfully scraped data for NOKIA C12 PRO 6GB* 64GB MINT (4GB + 2GB Virtual RAM)
# Successfully scraped data for Nokia 5710 XpressAudio keypad Phone, with inbuilt Wireless Earbuds, MP3 Player, Wireless FM Radio, Dedicated Music Buttons, and Bigger Battery | Black
# Successfully scraped data for HUAWEI nova Y72 Smart Phone, 6.75" FullView Display, 22.5W SuperCharge, 6000 mAh Super Battery, 50 MP AI Dual Camera, 8GB+128GB, EMUI 12, LTE, Black + Freebuds SE2 + 6 months VIU
# Successfully scraped data for Redmi 12C4+128 GB Graphite Gray +Redmi buds essential
# Successfully scraped data for جوال نوكيا جي 11 بلس، دي اس، 3GB-64GB، ازرق، بشريحتين
# Successfully scraped data for Nokia N73 (42 MB, White)
# Successfully scraped data for Samsung Galaxy S20 FE Mobile Phone; Sim Free Smartphone - 128 GB - Cloud Navy (UK Version)
# Successfully scraped data for Wiko T50 Dual Sim Aqua Green 6GB Ram 128GB 4G Lte
# Successfully scraped data for HONIKOVA Phone 5S، 16GB، تحتوي على وظيفة الاتصال، وظيفة البلوتوث، وظيفة التقاط الصور
# Successfully scraped data for Samsung Galaxy Z Flip4 Dual-Sim 512GB ROM + 8GB RAM (GSM only | No CDMA) Factory Unlocked 5G SmartPhone (Bora Purple) - International Version
# Successfully scraped data for Realme 12 Pro + 5G Dual SIM 8GB RAM 256GB (Navigator Beige)
# Successfully scraped data for Nokia 105 (2023) Dual-SIM Factory Unlocked 2G Keypad phone (Charcoal) - International Version
# Successfully scraped data for Sony Xperia 1 III - 6.5 Inch 21:9 Cinema Wide™ 4K HDR OLED display - 120Hz Refresh rate - Four lens options - Android 11 - SIM free - 12GB RAM - 512GB Storage - Dual SIM hybrid* - Frosted Black
# Successfully scraped data for OnePlus Nord 4 5G (Obsidian Midnight, 12GB RAM, 256GB Storage)
# Successfully scraped data for QIeCny Flip Phone for Seniors, A Backup Phone for Young And Old, 2.6 Inches Big Screen, Big Font/Loudspeakers/Dual Card Dual Standby, with MP3 Music Playback+One Key Fast Dial,Gold
# Successfully scraped data for POCO C50 (Royal Blue, 32 GB) (2 GB RAM)
# Successfully scraped data for HUAWEI P30 Pro 256 Gb Dual/Hybrid-Sim 4G Smartphone
# Successfully scraped data for Nokia C5 - Mini-SIM TFT Symbian 9.3 , 3.15MP Camera with LED flash (Black)
# Successfully scraped data for HONIKOVA 5.8 Inch XS Touch Screen Smartphone, 64G Storage Capacity, Support 4G Internet Download Software
# Successfully scraped data for OnePlus 11R 5G (16GB RAM, 256GB Storage, Galactic Silver)
# Successfully scraped data for OPPO Reno11 F 5G 256GB Storage, 8GB RAM, Android Smartphone Ocean Blue, 14.0 Colour OS Version, 67W Super VOOC Flash Charge, IP65 Water and Dust Resistance
# Successfully scraped data for Nubia Flip 5G (International Version) 256GB + 8GB RAM | 6.9" Dual SIM Factory Unlocked Android 13 Smartphone (Cosmic Black, 256GB + 8GB RAM)
# Successfully scraped data for HONOR 200 Pro 5G (Ocean Cyan, 12GB+512GB) | 6.78-inch AMOLED Quad-Curved Display | Dual OIS 50MP+50MP+12MP Camera | 50MP Selfie Camera | Snapdragon 8s Gen 3 | AI-Powered MagicOS 8.0 | Without Charger
# Successfully scraped data for Tecno Spark 20 Dual SIM Neon Gold 8GB RAM 256GB 4G - Middle East Version
# Successfully scraped data for L8star BM10 Wireless Earphone Dialer Dual SIM Card Mini Mobile Cellphone
# Successfully scraped data for Nokia c31 4g smartphone, 6.74'' hd+ display, 13+2+2 mp rear camera & led flash, 5mp front camera, 5050 mah battery, android 12, 2 years of security updates - cyan blue
# Successfully scraped data for Google هاتف خلوي من جوجل بيكسل 8 بشريحتين زجاج بركاني
# Successfully scraped data for ASUS ROG Phone 8, 256GB, 16GB RAM, Snapdragon 8 3G, 5G, International Version
# Successfully scraped data for Honor Magic 4 Pro 8GB RAM/256GB Storage Smartphone, 6.81 Inch Screen Size, Black
# Successfully scraped data for Honor Magic6 Lite Dual-SIM 256GB ROM + 8GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Midnight Black) - International Version
# Successfully scraped data for Nokia G21 Dual-SIM 128GB ROM + 4GB RAM (GSM Only | No CDMA) Factory Unlocked Android 4G/LTE Smartphone (Nordic Blue) - International Version
# Successfully scraped data for Tecno Camon 19 Neo (Eco Black, 6GB RAM, 128GB Storage)
# Successfully scraped data for SAMSUNG Galaxy Note 9 Single SIM - 128GB,6GB RAM,4G LTE - Midnight Black
# Successfully scraped data for Sony Xperia 5 IV - 6.1 Inch 21:9 Wide HDR OLED- 120Hz Refresh rate- Compact- Triple lens (with ZEISS T* coating)- 3.5 mm audio jack- Android 12- SIM free- 8GB RAM- 128GB Storage- Dual SIM hybrid-Black
# Successfully scraped data for Apple iPhone 14 Pro Max (1 TB) - Deep Purple
# Successfully scraped data for Keypad Mobile | Cell Phone | Mobile Phone | Mini 3110 Mobile Bm10
# Successfully scraped data for Samsung Galaxy Note20 Dual SIM Mystic Gray 8GB RAM 256GB 5G (KSA Version)
# Successfully scraped data for Samsung Galaxy A356E 5G,Android Smartphone, Dual SIM Mobile Phone, 6GB RAM, 128GB Storage, Awesome Ice Blue (KSA Version)
# Successfully scraped data for Google Pixel 9 - Unlocked Android Smartphone with Gemini, 24-Hour Battery, Advanced Camera, and 6.3" Actua Display - Porcelin - 128 GB
# Successfully scraped data for HONOR 200 LITE 8 GB RAM, 256 GB Dual NANO SIM 5G AI Empowered Magic Portal - Cyan Lake Include Gifts| HONOR earbuds X5 | HONOR Service Care+
# Successfully scraped data for NOKIA 6510 Seagull - silver
# Successfully scraped data for HASMI Flip Phone, 64x48 0.66 Inch 300mAh Battery Small Flip Phone 32MB 64MB for Elderly
# Successfully scraped data for Google Pixel 9 Pro - Unlocked Android Smartphone with Gemini, Triple Rear Camera System, 24-Hour Battery, and 6.3" Super Actua Display - Porcelain - 128 GB
# Successfully scraped data for OnePlus Nord 4 5G 16GB RAM 512GB Storage SIM-Free Smartphone with 50 MP Dual Camera + OIS - Mercurial Silver
# Successfully scraped data for motorola e32s,64GB ROM,4GB RAM,Slate Grey
# Successfully scraped data for OnePlus Open Dual-SIM 512GB ROM + 16GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Emerald Dusk) - International Version
# Successfully scraped data for Nokia 215 Dual-SIM 128MB ROM,64MB RAM, GSM, Factory Unlocked 4G/LTE Keypad Phone (Black) - International Version
# Successfully scraped data for HUAWEI P40 5G 8GB+128GB Black
# Successfully scraped data for Nokia 6310i - Silver
# Successfully scraped data for Itel A50 Dual SIM Lime Green 3+5GB RAM 128GB 4G - Middle East Version
# Successfully scraped data for Xiaomi 14T Dual SIM+eSIM Lemon Green 12GB RAM 512GB 5G - Global Version
# Successfully scraped data for Nokia 6300 -Movistar Sim Free-Black-Silver 100% Original Nokia Mobile
# Successfully scraped data for Sony Xperia 5 Dual SIM - 128GB, 6GB RAM, 4G LTE, Black
# Successfully scraped data for Honor X7a Dual SIM 6GB RAM 128GB 4G LTE Ocean Blue
# Successfully scraped data for HONOR Magic V3 5G Smartphone,9.2mm AI Foldable OLED Screen,12+512GB With Free Gifts,Sim Free,5150mAh All-day Battery,IPX8 Rating for Water Resistance,Snapdragon 8 Gen 2,Dual SIM, Android 14,Green
# Successfully scraped data for motorola G31, 128GB ROM, 4GB RAM, Baby Blue, regular
# Successfully scraped data for INOI Note 13s, 4G LTE, Octacore 8GB RAM + 256GB, 6.9” HD+ Display, Triple Camera, Space Grey
# Successfully scraped data for CAT PHONES Caterpillar S42 Smartphone - 4G Rugged Phone (IP68, MIL SPEC 810H, Super Bright 5.5” HD+ Display, 1.8GHz Quadcore Processor, 4200mAh Battery, Dual SIM, 3GB/32GB, Android 10) - Black
# Successfully scraped data for Oppo A79 5G Dual-SIM 128GB ROM + 4GB RAM (Only GSM | No CDMA) Factory Unlocked 5G Smartphone (Glowing Green) - International Version
# Successfully scraped data for Xiaomi POCO X5 5G (Black 6GB RAM, 128 Storage) 120Hz AMOLED Display Snapdragon 695 processor 33W fast charging [Amazon Exclusive], 128GB
# Successfully scraped data for C2-01 2G & 3G Mobile Phone (Black) Single SIM
# Successfully scraped data for HUAWEI Pura 70 Ultra Smartphone, Dual SIM, 16 + 512GB, Ultra Lighting Pop-out Camera, Starry Pattern Design, Ultra Speed Snapshot, Crystal Armour Kunlun Glass, 100W SuperCharge, Green(KSA Version)
# Successfully scraped data for Realme GT2 Dual-SIM 256GB ROM + 12GB RAM (GSM | CDMA) Factory Unlocked 5G SmartPhone (Paper White) - International Version
# Successfully scraped data for Xiaomi 12 Dual Sim 12GB Ram 256GB 5G Gray
# Successfully scraped data for Oppo A15S Dual Sim Smart Phone, 4Gb +64Gb Dynamic Black
# Successfully scraped data for OALE IP15 Plus 6.52 Inch Water Drop Screen Dual Sim 3GB RAM 32GB 5MP+8MP Camera 3G - Middle East Version (Iron Grey)
# Successfully scraped data for Xiaomi Redmi 10C 4G (Ocean Blue, 4GB RAM, 128 GB Storage)- Dot Drop Display | 50Mp With 5Mp Rare Camera
# Successfully scraped data for OPPO A16K Dual Sim Smartphone 32Gb 3Gb Ram, 6.52Inches Display, 4230Mah Long Lasting Battery, Uae Version 4G Lte Android Mobile Phone Unlocked Midnight Black, Cph2349, A16K Black
# Successfully scraped data for Samsung Galaxy A12 Dual SIM Smartphone - 64GB, 4GB RAM, 4G LTE, Blue (KSA Version)
# Successfully scraped data for LZFxmpy Senior Mobile Phone, 3 Inch Reverse Style, Home Unlocked Mobile Phone
# Successfully scraped data for 792 phones
# Data scraping and saving completed.

# %%
df1
# Out:
#                                                  Title    Brand  \
# 0                     Apple iPhone 16 (128 GB) - Black    Apple
# 1       Apple iPhone 16 Pro (256 GB) - Desert Titanium    Apple
# 2    Tecno Spark Go 2024 Dual SIM Magic Skin Green ...    Tecno
# 3    Xiaomi Redmi 14C Dual SIM Starry Blue 8GB RAM ...   Xiaomi
# 4     Coolpad CP12 Dual SIM Black 8GB RAM 128GB 4G LTE  Coolpad
# ..                                                 ...      ...
# 787  OALE IP15 Plus 6.52 Inch Water Drop Screen Dua...     OALE
# 788  Xiaomi Redmi 10C 4G (Ocean Blue, 4GB RAM, 128 ...   Xiaomi
# 789  OPPO A16K Dual Sim Smartphone 32Gb 3Gb Ram, 6....     OPPO
# 790  Samsung Galaxy A12 Dual SIM Smartphone - 64GB,...  SAMSUNG
# 791  LZFxmpy Senior Mobile Phone, 3 Inch Reverse St...  LZFxmpy
#
#                              OS    RAM             CPU Storage  Screen Size  \
# 0                        iOS 18   None            None  128 GB         None
# 1                        iOS 18   None            None  256 GB          5.8
# 2                  Android T Go   4 GB      Snapdragon  128 GB  6.56 Inches
# 3    Android 14, Xiaomi HyperOS   8 GB            None  256 GB  6.88 Inches
# 4                  Android 13.0   8 GB  MediaTek Helio  128 GB   6.5 Inches
# ..                          ...    ...             ...     ...          ...
# 787                Android 11.0   3 GB          Others   32 GB  6.52 Inches
# 788                Android 11.0   4 GB      Snapdragon  128 GB  6.71 Inches
# 789                Android 11.0   3 GB        A-Series   32 GB  6.52 Inches
# 790                Android 10.0   4 GB        A-Series   64 GB   6.5 Inches
# 791                        None  32 MB            None   32 MB            3
#
#       Resolution CPU Speed          Model  ... Wireless Technology  \
# 0           None      None      iPhone 16  ...            GSM, LTE
# 1           None      None  iPhone 16 Pro  ...               Wi-Fi
# 2     720 x 1612      1.60  Spark Go 2024  ...                None
# 3           None      None      Redmi 14C  ...                None
# 4           None     2 GHz           CP12  ...                None
# ..           ...       ...            ...  ...                 ...
# 787         None   2.3 GHz      IP15 Plus  ...                None
# 788  1080 x 1920   2.2 GHz      Redmi 10C  ...                None
# 789   720 x 1600      None     A16K Black  ...                None
# 790   1600 x 720   2.3 GHz     Galaxy A12  ...                None
# 791         None   1.9 GHz        LZFxmpy  ...                 GSM
#
#            Price Price Before Promotion  \
# 0    SAR3,375.00            SAR3,799.00
# 1    SAR4,787.00            SAR5,199.00
# 2      SAR259.00              SAR339.00
# 3      SAR509.00              SAR549.00
# 4      SAR288.00                   None
# ..           ...                    ...
# 787    SAR239.00                   None
# 788    SAR453.00                   None
# 789    SAR355.00                   None
# 790    SAR849.00                   None
# 791    SAR362.60                   None
#
#                                             Rate Camera  \
# 0                             4.2 out of 5 stars   48MP
# 1                             4.5 out of 5 stars   48MP
# 2                             3.9 out of 5 stars   None
# 3                             4.5 out of 5 stars   50MP
# 4                             3.8 out of 5 stars   13MP
# ..                                           ...    ...
# 787                                Previous page   None
# 788                           4.4 out of 5 stars   50MP
# 789                           3.8 out of 5 stars   None
# 790                           4.2 out of 5 stars   48MP
# 791  Previous page of related Sponsored Products   None
#
#                                                    IMG    Website Currancy  \
# 0    https://m.media-amazon.com/images/I/61-251PVEZ...  Amazon SA      SAR
# 1    https://m.media-amazon.com/images/I/617ZhMUCvI...  Amazon SA      SAR
# 2    https://m.media-amazon.com/images/I/61OWPJmPZ5...  Amazon SA      SAR
# 3    https://m.media-amazon.com/images/I/51bGRvjs8h...  Amazon SA      SAR
# 4    https://m.media-amazon.com/images/I/51WqzI4xmA...  Amazon SA      SAR
# ..                                                 ...        ...      ...
# 787  https://m.media-amazon.com/images/I/614SGxvK3E...  Amazon SA      SAR
# 788  https://m.media-amazon.com/images/I/61mzZSEiUX...  Amazon SA      SAR
# 789  https://m.media-amazon.com/images/I/51TKqn0SbO...  Amazon SA      SAR
# 790  https://m.media-amazon.com/images/I/81+47jA7LZ...  Amazon SA      SAR
# 791  https://m.media-amazon.com/images/I/51YumC9ndt...  Amazon SA      SAR
#
#                                                    URL  \
# 0    https://www.amazon.sa/-/en/Apple-iPhone-16-128...
# 1    https://www.amazon.sa/-/en/Apple-iPhone-16-Pro...
# 2    https://www.amazon.sa/-/en/Tecno-Spark-Magic-G...
# 3    https://www.amazon.sa/-/en/Xiaomi-Redmi-Dual-S...
# 4    https://www.amazon.sa/-/en/Coolpad-CP12-Dual-B...
# ..                                                 ...
# 787  https://www.amazon.sa/-/en/OALE-IP15-Plus-Scre...
# 788  https://www.amazon.sa/-/en/Xiaomi-Redmi-10C-St...
# 789  https://www.amazon.sa/-/en/OPPO-Smartphone-6-5...
# 790  https://www.amazon.sa/-/en/Samsung-Galaxy-A12-...
# 791  https://www.amazon.sa/-/en/LZFxmpy-Senior-Mobi...
#
#                                                Reviews
# 0    [Name: محمد غريس, Rating: 5.0 out of 5 stars, ...
# 1    [Name: SURESH MURUGAN, Rating: 5.0 out of 5 st...
# 2    [Name: رئع جداً, Rating: 5.0 out of 5 stars, D...
# 3    [Name: saeed hussain, Rating: 5.0 out of 5 sta...
# 4    [Name: Marivic mari-ay, Rating: 5.0 out of 5 s...
# ..                                                 ...
# 787                                                 []
# 788  [Name: eng elsheikh, Rating: 1.0 out of 5 star...
# 789  [Name: المنتج سيئ جدا التليفون بيفصل عيب صناعه...
# 790  [Name: Abdellateef Faisal Alhumidi, Rating: 5....
# 791                                                 []
#
# [792 rows x 25 columns]

# %% [markdown]
# # Then Cleaning The Scraped Data

# %%
import logging
import ast
import json
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
null = None
df=df1.copy()

def scrape_the_price(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
    }
    PageToScrape = requests.get(url, headers=headers)
    if PageToScrape.status_code == 200:
        soup = BeautifulSoup(PageToScrape.text, 'html.parser')
        convert_tag = soup.find('div', class_='YMlKec fxKbKc')
        convert = convert_tag.get_text(strip = True)
        return float(convert)
SAR_USD = scrape_the_price("https://www.google.com/finance/quote/SAR-USD")
EUR_USD = scrape_the_price("https://www.google.com/finance/quote/EUR-USD")
EGP_USD = scrape_the_price("https://www.google.com/finance/quote/EGP-USD")



def convert_price_before(value):
    value =str(value)
    if isinstance(value, str):
        try:
            value = value.upper()
            value = value.replace(',', '')
            value = value.replace('SAR','')
            value = value.replace('EUR','')
            value = value.replace('€','')
            return float(value)
        except ValueError:
            return None
    else:
        return None
def convert_rate(value):
    value =str(value)
    if isinstance(value, str):
        try:
            value = value.lower()
            value = value.replace(',', '')
            value = value.replace('out of 5 stars','')
            return float(value)
        except ValueError:
            return None
    else:
        return None
def convert_to_gb(value):
    value = str(value)
    if isinstance(value, str):
        value = value.replace(',', '')
        value = value.upper()
        if 'GB' in value:
            try:
                return float(value.replace('GB', ''))
            except ValueError:
                return np.nan
        elif 'MB' in value:
            try:
                return float(value.replace('MB', '')) / 1024 
            except ValueError:
                return np.nan
        elif 'TB' in value:
            try:
                return float(value.replace('TB', '')) * 1024 
            except ValueError:
                return np.nan
        elif 'LESS THAN' in value:
            return np.nan 
        else:
            return np.nan 
    elif isinstance(value, (int, float)):
        return float(value) 
    else:
        return np.nan
def convert_screen_size(value):
    value = str(value)
    value = value.upper()
    if 'INCHES' in value:
        value = value.replace('INCHES','')
        return float(value)
    elif 'INCH' in value:
        value = value.replace('INCH','')
        return float(value)
    else:
        return None
def convert_resolution(value):
    value = str(value)
    if value and isinstance(value, str):
        try:
            width, height = value.lower().split('x')
            width = float(width)
            height = float(height)
            return width, height
        except ValueError:
            return None, None
    else:
        return None, None
def change_price_to_USD(value,convert):
    if value :
        value = value*convert
        return value
    else:
        return None
def change_to_USD(value):
    return 'USD'
def find_cpu_in_title(title):
    cpu_sizes=['Octa Core', 'Hexa Core', 'Quad Core', 'Deca Core']
    if title:
        title_lower = title.lower()
        if 'cpu' in title_lower  :
            for cpu in cpu_sizes:
                if re.search(r'\b' + re.escape(cpu.lower()) + r'\b', title_lower, re.IGNORECASE):
                    return cpu
    return None
def find_color_in_title(title):
    allcolors = [
    "Rose Gold", "Navy Blue","Light Blue","Cobalt Violet","Awesome Graphite","Titanium Black","Wave Green","Emerald Green","Titanium Silver",
    "Midnight Blue", "Forest Green", "Pink", "Purple", "Lavender","Charcoal Ink","Carbon Grey","Glamorous Green","Flowing Silver",
    "Orange", "Bronze", "Copper", "Champagne", "Beige", "Coral", "Midnight Black","Cobalt Violet",
    "Turquoise", "Teal", "Mint Green", "Burgundy", "Aqua", "Cyan", "Lime Green","Rose Red",
    "Space Gray", "Graphite", "Alpine Green", "Starlight", "Pacific Blue", "Ceramic White","Moonlight White"
    "Jet Black", "Matte Black", "Phantom Black", "Phantom Silver", "Mystic Bronze", "Awesome Navy"
    "Mystic Green", "Cosmic Gray", "Cosmic Black", "Pearl White", "Glossy White", "Awesome Lime","Silver Shadow",
    "Aura Glow", "Aurora Blue", "Prism White", "Cloud Pink", "Midnight Green", "Mint","Charcoal",
    "Sunset Gold", "Ocean Blue", "Thunder Purple", "Starry Night", "Twilight", "Clear","Navy","Chartreuse",
    "Gradient Purple", "Gradient Blue", "Gradient Red","Gradient Pink", "Marble White", "Graphite","Violet",
    "Opal White", "Crystal Blue", "Ice Blue", "Sunrise Red", "Fiery Red","Blue","Black", "White", "Gray", "Silver", "Gold", "Red","Yellow", "Green", "Brown"
]
    for color in allcolors:
        if color.lower() in title.lower():
            return color
    return None
def find_strg_in_title(title):
    storage_sizes =["1TB","512GB", "256GB", "128GB", "64GB", "32GB", "16GB", "8GB"]
    if title:
        title_lower = title.lower()
        # Check for keywords related to RAM
        
        if 'storage' in title_lower  :
            for storage in storage_sizes:
                if re.search(r'\b' + re.escape(storage.lower()) + r'\b', title_lower, re.IGNORECASE):
                    return storage
    return None
def find_ram_in_title(title):
    ram_sizes = ["1GB","2GB", "3GB","4GB","6GB","8GB","12GB","16GB"]
    if title:
        title_lower = title.lower()
        # Check for keywords related to RAM
        if 'ram' in title_lower or 'memory' in title_lower:
            for ram in ram_sizes:
                if re.search(r'\b' + re.escape(ram.lower()) + r'\b', title_lower, re.IGNORECASE):
                    return ram
    return None
df_sa=df
df_sa.columns = [col.lower() for col in df_sa.columns]
df_sa.rename(columns={'main camera': 'camera', 'network': 'cellular technology','number of sim':'sim count',}, inplace=True)
df_sa['CPU'] = df_sa.apply(lambda row: find_cpu_in_title(row['title']) or row['cpu'], axis=1)
df_sa['color'] = df_sa.apply(lambda row: find_color_in_title(row['title']) or row['color'], axis=1)
df_sa['Storage'] = df_sa.apply(lambda row: find_strg_in_title(row['title']) or row['storage'], axis=1)
df_sa['RAM'] = df_sa.apply(lambda row: find_ram_in_title(row['title']) or row['ram'], axis=1)
df_sa['ram'] = df_sa['ram'].fillna(df_sa['RAM'])
df_sa['storage'] = df_sa['storage'].fillna(df_sa['Storage'])
df_sa['cpu'] = df_sa['cpu'].fillna(df_sa['CPU'])
df_sa=df_sa.drop(['Storage','CPU','RAM'], axis=1)
df_sa['storage'] = df_sa['storage'].apply(convert_to_gb)
df_sa['ram'] = df_sa['ram'].apply(convert_to_gb)
df_sa['screen size'] = df_sa['screen size'].apply(convert_screen_size)
df_sa[['width resolution', 'height resolution']] = df_sa['resolution'].apply(convert_resolution).apply(pd.Series)
df_sa['price'] = df_sa['price'].apply(convert_price_before).apply(lambda x: change_price_to_USD(x, SAR_USD))
df_sa['price before promotion'] = df_sa['price before promotion'].apply(convert_price_before).apply(lambda x: change_price_to_USD(x, SAR_USD))
df_sa['rate'] = df_sa['rate'].apply(convert_rate)
df_sa['currancy'] = df_sa['currancy'].apply(change_to_USD)
df_sa
# Out:
#                                                  title    brand  \
# 0                     Apple iPhone 16 (128 GB) - Black    Apple
# 1       Apple iPhone 16 Pro (256 GB) - Desert Titanium    Apple
# 2    Tecno Spark Go 2024 Dual SIM Magic Skin Green ...    Tecno
# 3    Xiaomi Redmi 14C Dual SIM Starry Blue 8GB RAM ...   Xiaomi
# 4     Coolpad CP12 Dual SIM Black 8GB RAM 128GB 4G LTE  Coolpad
# ..                                                 ...      ...
# 787  OALE IP15 Plus 6.52 Inch Water Drop Screen Dua...     OALE
# 788  Xiaomi Redmi 10C 4G (Ocean Blue, 4GB RAM, 128 ...   Xiaomi
# 789  OPPO A16K Dual Sim Smartphone 32Gb 3Gb Ram, 6....     OPPO
# 790  Samsung Galaxy A12 Dual SIM Smartphone - 64GB,...  SAMSUNG
# 791  LZFxmpy Senior Mobile Phone, 3 Inch Reverse St...  LZFxmpy
#
#                              os      ram             cpu    storage  \
# 0                        iOS 18      NaN            None  128.00000
# 1                        iOS 18      NaN            None  256.00000
# 2                  Android T Go  4.00000      Snapdragon  128.00000
# 3    Android 14, Xiaomi HyperOS  8.00000            None  256.00000
# 4                  Android 13.0  8.00000  MediaTek Helio  128.00000
# ..                          ...      ...             ...        ...
# 787                Android 11.0  3.00000          Others   32.00000
# 788                Android 11.0  4.00000      Snapdragon  128.00000
# 789                Android 11.0  3.00000        A-Series   32.00000
# 790                Android 10.0  4.00000        A-Series   64.00000
# 791                        None  0.03125            None    0.03125
#
#      screen size   resolution cpu speed          model  ...  \
# 0            NaN         None      None      iPhone 16  ...
# 1            NaN         None      None  iPhone 16 Pro  ...
# 2           6.56   720 x 1612      1.60  Spark Go 2024  ...
# 3           6.88         None      None      Redmi 14C  ...
# 4           6.50         None     2 GHz           CP12  ...
# ..           ...          ...       ...            ...  ...
# 787         6.52         None   2.3 GHz      IP15 Plus  ...
# 788         6.71  1080 x 1920   2.2 GHz      Redmi 10C  ...
# 789         6.52   720 x 1600      None     A16K Black  ...
# 790         6.50   1600 x 720   2.3 GHz     Galaxy A12  ...
# 791          NaN         None   1.9 GHz        LZFxmpy  ...
#
#     price before promotion rate camera  \
# 0                1010.9139  4.2   48MP
# 1                1383.4539  4.5   48MP
# 2                  90.2079  3.9   None
# 3                 146.0889  4.5   50MP
# 4                      NaN  3.8   13MP
# ..                     ...  ...    ...
# 787                    NaN  NaN   None
# 788                    NaN  4.4   50MP
# 789                    NaN  3.8   None
# 790                    NaN  4.2   48MP
# 791                    NaN  NaN   None
#
#                                                    img    website currancy  \
# 0    https://m.media-amazon.com/images/I/61-251PVEZ...  Amazon SA      USD
# 1    https://m.media-amazon.com/images/I/617ZhMUCvI...  Amazon SA      USD
# 2    https://m.media-amazon.com/images/I/61OWPJmPZ5...  Amazon SA      USD
# 3    https://m.media-amazon.com/images/I/51bGRvjs8h...  Amazon SA      USD
# 4    https://m.media-amazon.com/images/I/51WqzI4xmA...  Amazon SA      USD
# ..                                                 ...        ...      ...
# 787  https://m.media-amazon.com/images/I/614SGxvK3E...  Amazon SA      USD
# 788  https://m.media-amazon.com/images/I/61mzZSEiUX...  Amazon SA      USD
# 789  https://m.media-amazon.com/images/I/51TKqn0SbO...  Amazon SA      USD
# 790  https://m.media-amazon.com/images/I/81+47jA7LZ...  Amazon SA      USD
# 791  https://m.media-amazon.com/images/I/51YumC9ndt...  Amazon SA      USD
#
#                                                    url  \
# 0    https://www.amazon.sa/-/en/Apple-iPhone-16-128...
# 1    https://www.amazon.sa/-/en/Apple-iPhone-16-Pro...
# 2    https://www.amazon.sa/-/en/Tecno-Spark-Magic-G...
# 3    https://www.amazon.sa/-/en/Xiaomi-Redmi-Dual-S...
# 4    https://www.amazon.sa/-/en/Coolpad-CP12-Dual-B...
# ..                                                 ...
# 787  https://www.amazon.sa/-/en/OALE-IP15-Plus-Scre...
# 788  https://www.amazon.sa/-/en/Xiaomi-Redmi-10C-St...
# 789  https://www.amazon.sa/-/en/OPPO-Smartphone-6-5...
# 790  https://www.amazon.sa/-/en/Samsung-Galaxy-A12-...
# 791  https://www.amazon.sa/-/en/LZFxmpy-Senior-Mobi...
#
#                                                reviews  width resolution  \
# 0    [Name: محمد غريس, Rating: 5.0 out of 5 stars, ...               NaN
# 1    [Name: SURESH MURUGAN, Rating: 5.0 out of 5 st...               NaN
# 2    [Name: رئع جداً, Rating: 5.0 out of 5 stars, D...             720.0
# 3    [Name: saeed hussain, Rating: 5.0 out of 5 sta...               NaN
# 4    [Name: Marivic mari-ay, Rating: 5.0 out of 5 s...               NaN
# ..                                                 ...               ...
# 787                                                 []               NaN
# 788  [Name: eng elsheikh, Rating: 1.0 out of 5 star...            1080.0
# 789  [Name: المنتج سيئ جدا التليفون بيفصل عيب صناعه...             720.0
# 790  [Name: Abdellateef Faisal Alhumidi, Rating: 5....            1600.0
# 791                                                 []               NaN
#
#     height resolution
# 0                 NaN
# 1                 NaN
# 2              1612.0
# 3                 NaN
# 4                 NaN
# ..                ...
# 787               NaN
# 788            1920.0
# 789            1600.0
# 790             720.0
# 791               NaN
#
# [792 rows x 27 columns]
